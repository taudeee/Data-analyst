# %% [markdown]
# <a href="https://colab.research.google.com/github/taudeee/Data-analyst/blob/main/datacleaninpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **lets learn about data cleaning**

# %%
#lets import file
import pandas as pd
df = pd.read_excel('/Customer Call List.xlsx')

df.head()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# **lets start with dropping duplicates**

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# **lets remove columns **

# %%
df = df.drop(columns = 'Not_Useful_column')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-e9a3cdf36508> in <cell line: 1>()
# ----> 1 df = df.drop(columns = 'Not_Useful_column')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %% [markdown]
# let clean NAN

# %%
 df['last_Name'] = df['Last_Name'].str.lstrip("/")
 df['last_Name'] = df['Last_Name'].str.lstrip("...")
 df['last_Name'] = df['Last_Name'].str.rstrip("_")
 df

 #above line of code can be done in this line of code

df['Last_name'] = df['Last_Name'].str.strip("123._/")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Last_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-ef468937aa22> in <cell line: 1>()
# ...

# %%
df = pd.read_excel('/Customer Call List.xlsx')
df
df = df.drop_duplicates() #this will drop duplicates
df
df = df.drop(columns ='Not_Useful_Column')
df
df['Last_Name'] = df['Last_Name'].str.strip('123./_')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# lets deal with phone number

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
df
# Out:
# <ipython-input-47-a8eaa71f8241>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# ...

# %%
df['Phone_Number'].apply(lambda x:str(x))
df
df['Phone_Number'].apply(lambda x: x[0:3] + ' ' + x[3:6] + ' ' + [6:10])
# Out:
#   File "<ipython-input-54-50b85af807a5>", line 3
#     df['Phone_Number'].apply(lambda x: x[0:3] + ' ' + x[3:6] + ' ' + [6:10])
#                                                                        ^
# SyntaxError: invalid syntax

# %%
#df['Phone_Number'].apply(lambda x:str(x))
df['Phone_Number'].apply(lambda x: x[0:3]+ ' ' + x[3:6] + ' ' +x[6:10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-a817f3c70838> in <cell line: 2>()
#       1 #df['Phone_Number'].apply(lambda x:str(x))
# ----> 2 df['Phone_Number'].apply(lambda x: x[0:3]+ ' ' + x[3:6] + ' ' +x[6:10])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
# ...

# %%
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
#lets look address
df[['Street_address', 'State', 'Zip_code']]=df["Address"].str.split(',',2, expand=True)
df
# Out:
# <ipython-input-66-23cd66307157>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Street_address', 'State', 'Zip_code']]=df["Address"].str.split(',',2, expand=True)
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# ...

# %%
df = df.drop(columns = "Address")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-24d9685bbbf5> in <cell line: 1>()
# ----> 1 df = df.drop(columns = "Address")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White          NaN               N
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter          NaN               Y
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %% [markdown]
# lets learn about replacing

# %%
df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'].str.replace('No', 'N')
# Out:
# 0     Yes
# 1       N
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6       N
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15      N
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df = df.replace('N/a', '')
df = df.replace('NaN', '')

# %%
df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White          NaN               N
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter          NaN               Y
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White          NaN               N
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter          NaN               Y
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %%
for x in df.index:
  if df.loc[x, "Do_Not_Contact"] == "Y":
    df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White          NaN               N
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          NaN              No
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          NaN             Yes
# 11        1012      Harry      Potter          NaN               Y
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/Customer Call List.csv')
df.head()
df.tail()
#df.groupby('columnname').mean().sort_values(by="")
df.columns
df2 = df.transpose()
df2
df.info()
df.dtypes
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
#  8   Unnamed: 8         0 non-null      float64
#  9   Unnamed: 9         0 non-null      float64
# dtypes: bool(1), float64(2), int64(1), object(6)
# memory usage: 1.6+ KB
# CustomerID            0
# First_Name            0
# Last_Name             1
# Phone_Number          2
# Address               0
# Paying Customer       0
# Do_Not_Contact        4
# Not_Useful_Column     0
# ...

# %% [markdown]
# **lets start with removing columns**

# %%
df
#duplicates
#in last_number we have unwanted string
#phone number are not standard format
#address let seperate them
#unwanted columns
#and manymore
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# **lets start with removing duplicates**

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# **lets remove columns**

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-8042a8ec755a> in <cell line: 1>()
# ----> 1 df = df.drop(columns = "Not_Useful_Column")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# **lets clean the unwanted things
# in the number**

# %%
df['Last_Name'].str.strip() #it change white space
df['Last_Name'].str.lstrip("...") #it removed the ... from left side
df['Last_Name'].str.rstrip("_")
df['Last_Name'].str.lstrip("/")
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# we want to change it just for last_name
# we can do it by following **bold text**

# %%
df
df["Last_Name"] = df["Last_Name"].str.lstrip("/")
df["Last_Name"] = df["Last_Name"].str.lstrip("...")
df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df
#the above can be done in following steps
#df["Last_Name"] = df["Last_Name"].str.strip("123._/")
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %% [markdown]
# **lets clean the number**

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
df
# Out:
# <ipython-input-36-a8eaa71f8241>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# ...

# %%
df["Phone_Number"].apply(lambda x: x[0-3]+ '-' + [3-6]+ '-' + [6-9])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-a26d2a5f406e> in <cell line: 1>()
# ----> 1 df["Phone_Number"].apply(lambda x: x[0-3]+ '-' + [3-6]+ '-' + [6-9])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# ...

# %%
#in the above code
#we have string and float
#lets make them same data types

# %%
df["Phone_Number"] = df["Phone_Number"].apply(str)
df
df["Phone_Number"].apply(lambda x: str(x))
df["Phone_Number"].apply(lambda x: x[0-3]+ '-' + [3-6]+ '-' + [6-9])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-1e33c6817a39> in <cell line: 4>()
#       2 df
#       3 df["Phone_Number"].apply(lambda x: str(x))
# ----> 4 df["Phone_Number"].apply(lambda x: x[0-3]+ '-' + [3-6]+ '-' + [6-9])
#       5
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
df
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
df
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3]+'-'+ [3:6]+ '-'+[6:10])
# Out:
#   File "<ipython-input-55-96efe2f16412>", line 4
#     df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3]+'-'+ [3:6]+ '-'+[6:10])
#                                                                           ^
# SyntaxError: invalid syntax

# %%
df["Phone_Number"] = df["Phone_Number"].replace('Na--','')
df["Phone_Number"] = df["Phone_Number"].replace('nan--','')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %% [markdown]
# lets change the address into different columns

# %%
#lets look address
df[['Street_address', 'State', 'Zip_code']]=df["Address"].str.split(',',2, expand=True)
df
# Out:
# <ipython-input-61-23cd66307157>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Street_address', 'State', 'Zip_code']]=df["Address"].str.split(',',2, expand=True)
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter   7066950392
# ...

# %% [markdown]
# **lets delete address**

# %%
df = df.drop(columns = "Address")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-24d9685bbbf5> in <cell line: 1>()
# ----> 1 df = df.drop(columns = "Address")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467             Yes
# 6         1007       Jeff      Winger          nan              No
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na             Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 10        1011    Samwise      Gamgee          nan             Yes
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345             Yes
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace('Yes', 'Y')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775              No
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          nan              No
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace('No', 'N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775               N
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# ...

# %%
df = df.replace('N/a','')
df
df = df.replace('Nan', '')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775               N
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf         NaN           Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# ...

# %% [markdown]
# lets fill

# %%
df = df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775               N
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf                       Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].replace('No', 'N')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775               N
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf                       Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].replace('Yes', 'Y')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 1         1002       Abed       Nadir   1236439775               N
# 2         1003     Walter       White   7066950392               N
# 3         1004     Dwight     Schrute   1235432345               Y
# 4         1005        Jon        Snow   8766783469               Y
# 5         1006        Ron     Swanson   3047622467               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf                       Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# ...

# %%
for x in df.index:
  if df.loc[x, "Do_Not_Contact"] == "Y":
    df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 2         1003     Walter       White   7066950392               N
# 4         1005        Jon        Snow   8766783469               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf                       Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# 13        1014     Leslie       Knope   8766783469               Y
# 14        1015       Toby  Flenderson   3047622467               N
# 15        1016        Ron     Weasley   1235455421               N
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].replace('', 'N')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 2         1003     Walter       White   7066950392               N
# 4         1005        Jon        Snow   8766783469               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf                       Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# 13        1014     Leslie       Knope   8766783469               Y
# 14        1015       Toby  Flenderson   3047622467               N
# 15        1016        Ron     Weasley   1235455421               N
# ...

# %%
 df["Phone_Number"] = df["Phone_Number"].replace['nan', 'Y']
 df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-137ffb46d659> in <cell line: 1>()
# ----> 1 df["Phone_Number"] = df["Phone_Number"].replace['nan', 'Y']
#       2 df
#
# TypeError: 'method' object is not subscriptable

# %%
df.reset_index(drops=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-c11024c48f38> in <cell line: 1>()
# ----> 1 df.reset_index(drops=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# TypeError: DataFrame.reset_index() got an unexpected keyword argument 'drops'

# %%
df.dropna(subset=["Phone_Number"], inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421               Y
# 2         1003     Walter       White   7066950392               N
# 4         1005        Jon        Snow   8766783469               Y
# 6         1007       Jeff      Winger          nan               N
# 7         1008   Sherlock      Holmes   8766783469               N
# 8         1009    Gandalf                       Na               Y
# 9         1010      Peter      Parker   1235455421               Y
# 10        1011    Samwise      Gamgee          nan               Y
# 11        1012      Harry      Potter   7066950392               Y
# 12        1013        Don      Draper   1235432345               Y
# 13        1014     Leslie       Knope   8766783469               Y
# 14        1015       Toby  Flenderson   3047622467               N
# 15        1016        Ron     Weasley   1235455421               N
# ...
